# %% [markdown]
# ## Class Project 1

# %% [markdown]
# ## Top Apps in Google Play

# %%
#The first 7 rows of the Google Play dataset
import pandas as pd
len = 7
data = pd.read_csv("google_dataset.csv")
for row in range(len):
    df = data.iloc[row]
    print(df)

# %%
#The first 3 columns of the Google Play dataset
import pandas as pd
data = pd.read_csv("google_dataset.csv")
df = pd.DataFrame(data)
columns = list(df)
df[['App Name','App ID','Category']]
# Out:
#                                              App Name  \
# 0                                Google Play services
# 1                                             YouTube
# 2                                              Google
# 3                    Google Maps - Navigate & Explore
# 4                               Google Text-to-Speech
# ..                                                ...
# 65                                              Clock
# 66  Spotify: Listen to podcasts & find music you love
# 67                                   Google Translate
# 68                                      Samsung Notes
# 69                                         Calculator
#
#                                      App ID                 Category
# 0                    com.google.android.gms                    Tools
# 1                com.google.android.youtube  Video Players & Editors
# 2   com.google.android.googlequicksearchbox                    Tools
# ...

# %%
#Only one row and header of the Google Play dataset
import pandas as pd
data = pd.read_csv("google_dataset.csv")

df = data.head(1)
df

# %% [markdown]
# ## Cryptocurrency Predict Artificial Intelligence V3

# %%
#The first 7 rows of the Cryptocurrency dataset
import pandas as pd
len = 7
data = pd.read_csv("crypt_dataset.csv")
for row in range(len):
    df = data.iloc[row]
    print(df)

# %%
#The first 3 columns of the Cryptocurrency dataset
import pandas as pd
data = pd.read_csv("crypt_dataset.csv")
df = pd.DataFrame(data)
columns = list(df)
df[['Date','Price','Open']]

# %%
#Only one row and header of the Cryptocurrency dataset
import pandas as pd
data = pd.read_csv("crypt_dataset.csv")

df = data.head(1)
df

# %% [markdown]
# ## Programming Laungages and File Format Detection

# %%
#The first 7 rows of the Programming Laungages dataset
import pandas as pd
len = 7
data = pd.read_csv("lang_dataset.csv")
for row in range(len):
    df = data.iloc[row]
    print(df)

# %%
#The first 3 columns of the Programming Laungages dataset
import pandas as pd
data = pd.read_csv("lang_dataset.csv")
df = pd.DataFrame(data)
columns = list(df)
df[['id','file_path','file_size']]
# Out:
#           id                     file_path  file_size
# 0          1  ./dataset\Markdown\000001.md      34784
# 1          2    ./dataset\XML\000002.props       3013
# 2          3     ./dataset\Text\000003.txt       1076
# 3          4  ./dataset\Markdown\000004.md       8105
# 4          5  ./dataset\Markdown\000005.md       2763
# ...      ...                           ...        ...
# 85139  85140  ./dataset\Swift\085140.swift        901
# 85140  85141  ./dataset\Swift\085141.swift       1870
# 85141  85142  ./dataset\Swift\085142.swift       2223
# 85142  85143  ./dataset\Swift\085143.swift       1106
# 85143  85144  ./dataset\Swift\085144.swift       1522
#
# [85144 rows x 3 columns]

# %%
#Only one row and header of the Programming Laungages dataset
import pandas as pd
data = pd.read_csv("lang_dataset.csv")

df = data.head(1)
df
